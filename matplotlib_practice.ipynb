# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis, y_axis)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x_axis,y_axis)

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
plt.plot(x_axis, y_axis)
plt.show()

# %%
# Create the plot and add the label for the legend
plt.plot(x_axis, y_axis, marker = "*", color="blue", linewidth=2, label= 'Boston')
# Create labels for x and y axis
plt.xlabel('Date')
plt.ylabel('Fare($)')
# Set the y limit between 0 and 45
plt.ylim(0,45)
# Create a title
plt.title('Pyber Fare by Month')
# Add a grid
plt.grid()
plt.legend()

# %%
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis, marker = "D", color = "green", linewidth = 2, label = "Boston")
# Set the labels
ax.set_xlabel('Date')
ax.set_ylabel('Fare($)')
# Set Y limit between 0 and 45
ax.set_ylim(0,45)
# Create a title
ax.set_title("Object Oriented Pyber by Month")
# Add a gird
ax.grid()
# Add a legned
ax.legend()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.bar(x_axis, y_axis, color = 'green', label = "Boston")
plt.xlabel('Date')
plt.ylabel('Fares($0)')
# Create a title
plt.title("MatLab Bar Pyber by Month")
# Add the lengend
plt.legend()

# %%
# Create the chart
plt.barh(x_axis,y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Opposite axis, changed the order of the x and y variables
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color = "cyan", label = 'Chicago')
ax.set_xlabel('Fare($)')
ax.set_ylabel('Months')
ax.set_title('PyBer Fare by Month n Stuff')
ax.invert_yaxis()

# %%
x = [50, 42, 39, 34, 32, 48, 22, 17, 8, 13]
y = [17, 19, 21, 22, 24, 23, 34, 31, 43, 35]

# %%
plt.scatter(x,y , c = 'green', marker = 'x', s=x)
plt.xlabel('Total Number of Rides (per City)')
plt.ylabel('Average Fare($)')
plt.title('Total Fare vs. Number of Rides')
plt.show()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# Plot it
plt.plot(x_axis, y_axis, 'o')

# %%
plt.scatter(y_axis, x_axis, color= 'red', label= 'Chicago')
plt.ylabel('Months')
plt.xlabel('Fare ($)')
plt.title('Pyber Fares by Month')
plt.xlim(0,50)
plt.gca().invert_yaxis()

# %%
plt.scatter(x_axis,y_axis, s= y_axis)

# %%
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)

# %%
plt.scatter(x_axis,y_axis, s= y_axis_larger)

# %%
plt.scatter(x_axis, y_axis, s = [i*3 for i in y_axis])

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, color= 'skyblue', s= [i*5 for i in y_axis], alpha = '.8', edgecolors = 'black', linewidth = 2, label = 'Boston')
ax.legend()
ax.set_title('Pyber Outlined Transparent Practice')
ax.legend()

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
plt.subplots(figsize=(8,8))
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode= explode_values, labels=x_axis, colors = colors, autopct= '%.1f%%' )
# Out:
# ([<matplotlib.patches.Wedge at 0x1af5eaa9788>,
#   <matplotlib.patches.Wedge at 0x1af5eaa9f88>,
#   <matplotlib.patches.Wedge at 0x1af5eaafe48>,
#   <matplotlib.patches.Wedge at 0x1af5eab6d48>,
#   <matplotlib.patches.Wedge at 0x1af5faa10c8>,
#   <matplotlib.patches.Wedge at 0x1af5faa8108>,
#   <matplotlib.patches.Wedge at 0x1af5faa8c88>,
#   <matplotlib.patches.Wedge at 0x1af5faadc08>,
#   <matplotlib.patches.Wedge at 0x1af5eabbc88>,
#   <matplotlib.patches.Wedge at 0x1af5faa1cc8>,
#   <matplotlib.patches.Wedge at 0x1af5fac0948>,
#   <matplotlib.patches.Wedge at 0x1af5fac78c8>],
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.3293082697128627, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452758, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.2333875250754619, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.4609812999807629, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.27265269033713785, 0.5344721793058277, '13.0%'),
#   Text(-0.17962269257065236, 0.5724820419136908, '11.7%'),
#   Text(-0.5076109522933946, 0.3198923586330143, '10.7%'),
#   Text(-0.5990928836323088, -0.03298055155883322, '8.9%'),
#   Text(-0.562131093819659, -0.5692175624145076, '14.5%'),
#   Text(-0.12730228640479738, -0.5863396011494626, '3.5%'),
#   Text(0.011507759568770587, -0.5998896327406462, '3.9%'),
#   Text(0.2514443454440525, -0.5447712741547703, '9.2%'),
#   Text(0.4837476184637258, -0.35494822387310737, '6.9%'),
#   Text(0.5869610808263387, -0.12440534391727841, '6.6%')])

# %%
fig, ax = plt.subplots(figsize=(8,8))
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
ax.pie(y_axis, labels=x_axis, explode = explode_values, shadow = True, startangle = 84, autopct ='%.1f%%', colors = colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x1af5fadf408>,
#   <matplotlib.patches.Wedge at 0x1af5fb96b88>,
#   <matplotlib.patches.Wedge at 0x1af5fc3eac8>,
#   <matplotlib.patches.Wedge at 0x1af5fc49908>,
#   <matplotlib.patches.Wedge at 0x1af5ea87508>,
#   <matplotlib.patches.Wedge at 0x1af5fc4a248>,
#   <matplotlib.patches.Wedge at 0x1af5ea82288>,
#   <matplotlib.patches.Wedge at 0x1af5fb21188>,
#   <matplotlib.patches.Wedge at 0x1af5ea87f48>,
#   <matplotlib.patches.Wedge at 0x1af5fc4a908>,
#   <matplotlib.patches.Wedge at 0x1af5e80dec8>,
#   <matplotlib.patches.Wedge at 0x1af5ffd2548>],
#  [Text(0.0006060867735291145, 1.099999833026725, 'Jan'),
#   Text(-0.37224694621671334, 1.0351000971076816, 'Feb'),
#   Text(-1.089929355792574, 0.7085576895225856, 'Mar'),
#   Text(-1.0782229505863048, -0.2177963930577443, 'April'),
#   Text(-0.6805328706047505, -0.8642193078301699, 'May'),
#   Text(-0.054674359362499016, -1.0986403935903233, 'June'),
#   Text(0.8244285231933567, -1.0051455666445637, 'July'),
#   Text(1.044671575009863, -0.34447249580541595, 'Aug'),
#   Text(1.095978148812034, -0.09397817473513428, 'Sept'),
#   Text(1.041461760425532, 0.35405847196663975, 'Oct'),
#   Text(0.7398768218073564, 0.8139915776912225, 'Nov'),
#   Text(0.3393096267059613, 1.04635986984625, 'Dec')],
#  [Text(0.0003305927855613351, 0.5999999089236682, '3.3%'),
#   Text(-0.20304378884547997, 0.5646000529678262, '7.7%'),
#   Text(-0.6707257574108147, 0.43603550124466806, '13.0%'),
#   Text(-0.5881216094107116, -0.1187980325769514, '11.7%'),
#   Text(-0.37119974760259117, -0.47139234972554717, '10.7%'),
#   Text(-0.02982237783409037, -0.5992583965038126, '8.9%'),
#   Text(0.5073406296574502, -0.6185511179351161, '14.5%'),
#   Text(0.5698208590962889, -0.18789408862113594, '3.5%'),
#   Text(0.597806262988382, -0.051260822582800514, '3.9%'),
#   Text(0.5680700511411992, 0.1931228028908944, '9.2%'),
#   Text(0.4035691755312853, 0.44399540601339404, '6.9%'),
#   Text(0.18507797820325161, 0.5707417471888636, '6.6%')])
